# %%
import pandas as pd

# %%
# load dataset

# %%
df = pd.read_csv("Medical Appointment No Shows.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841190e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572130e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596270e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557660e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213490e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775120e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
# check the Missing values

# %%
missing= df.isnull().sum()
missing
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
 #Drop duplicate rows

# %%
df.drop_duplicates(inplace=True)

# %%
# 4. Standardize text values (example: gender column)

# %%
if 'gender' in df.columns:
    df['gender'] = df['gender'].str.upper().str.strip()

# %%
# 5. Convert date columns to datetime format

# %%
for col in df.columns:
    if 'date' in col:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# 6. Fix data types (example: age should be int)

# %%
if 'age' in df.columns:
    df['age'] = df['age'].astype(int)

# %%
df.to_csv("cleaned_medical_appointments.csv", index=False)

# %%
# Display a short summary of changes
summary = {
    "Total Rows After Cleaning": len(df),
    "Missing Values (after cleaning)": df.isnull().sum().to_dict(),
    "Column Types": df.dtypes.to_dict()
}

print(summary)
# Out:
# {'Total Rows After Cleaning': 110527, 'Missing Values (after cleaning)': {'PatientId': 0, 'AppointmentID': 0, 'Gender': 0, 'ScheduledDay': 0, 'AppointmentDay': 0, 'Age': 0, 'Neighbourhood': 0, 'Scholarship': 0, 'Hipertension': 0, 'Diabetes': 0, 'Alcoholism': 0, 'Handcap': 0, 'SMS_received': 0, 'No-show': 0}, 'Column Types': {'PatientId': dtype('float64'), 'AppointmentID': dtype('int64'), 'Gender': dtype('O'), 'ScheduledDay': dtype('O'), 'AppointmentDay': dtype('O'), 'Age': dtype('int64'), 'Neighbourhood': dtype('O'), 'Scholarship': dtype('int64'), 'Hipertension': dtype('int64'), 'Diabetes': dtype('int64'), 'Alcoholism': dtype('int64'), 'Handcap': dtype('int64'), 'SMS_received': dtype('int64'), 'No-show': dtype('O')}}
